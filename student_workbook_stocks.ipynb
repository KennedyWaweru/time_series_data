# %% [markdown]
# # Getting Started with Python
#
# ## Time Series Data : Analysing Stocks
#
# #### __Author__ : Your Name
#
# #### __Date__: 16/3/2022

# %% [markdown]
# ### Resources
#
# Download the dataset and move it to your working directory.
#
# If you want to know your working directory just input the following commands:

# %%
import os

os.getcwd()
# Out:
# 'C:\\Users\\Just Nick\\Desktop\\Time Series'

# %% [markdown]
# Make sure the dataset you have downloaded is in the working directory:

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints', 'new_daily_prices.csv', 'student_workbook_stocks.ipynb']

# %% [markdown]
# ### Load the necessary modules

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from datetime import datetime

# %% [markdown]
# ### Load the data into a DataFrame
#
# We use `pandas.read_csv()`

# %%
df = pd.read_csv('new_daily_prices.csv')

# %%
df.head()
# Out:
#                      Date  Eaagads Ltd Ord 1.25 AIMS  Kakuzi Ord.5.00  \
# 0   Thursday, 13 May 2021                       15.0           360.00
# 1     Friday, 21 May 2021                       15.0           360.00
# 2    Tuesday, 25 May 2021                       15.0           360.00
# 3    Monday, 19 July 2021                       11.0           372.75
# 4   Tuesday, 27 July 2021                       11.5           410.00
#
#    Limuru Tea Co. Ltd Ord 20.00  Sasini Ltd Ord 1.00  \
# 0                         340.0                18.80
# 1                         340.0                18.55
# 2                         340.0                18.40
# 3                         290.0                19.20
# 4                         280.0                19.95
#
#    Williamson Tea Kenya Ltd Ord 5.00  Car and General (K) Ltd Ord 5.00  \
# 0                             146.75                              20.5
# 1                             145.00                              22.0
# ...

# %%
df.tail()
# Out:
#                             Date  Eaagads Ltd Ord 1.25 AIMS  Kakuzi Ord.5.00  \
# 102   Wednesday, 05 January 2022                      12.85            420.0
# 103    Thursday, 06 January 2022                      13.80            420.0
# 104      Friday, 07 January 2022                      13.80            420.0
# 105     Tuesday, 11 January 2022                      13.80            385.0
# 106    Thursday, 13 January 2022                      12.90            385.0
#
#      Limuru Tea Co. Ltd Ord 20.00  Sasini Ltd Ord 1.00  \
# 102                         320.0                19.95
# 103                         320.0                20.25
# 104                         320.0                21.25
# 105                         320.0                20.55
# 106                         320.0                22.20
#
#      Williamson Tea Kenya Ltd Ord 5.00  Car and General (K) Ltd Ord 5.00  \
# 102                             130.75                             30.60
# ...

# %%
df1 =  pd.read_csv('new_daily_prices.csv', index_col=0)
df1.head()
# Out:
#                         Eaagads Ltd Ord 1.25 AIMS  Kakuzi Ord.5.00  \
# Date
#  Thursday, 13 May 2021                       15.0           360.00
#  Friday, 21 May 2021                         15.0           360.00
#  Tuesday, 25 May 2021                        15.0           360.00
#  Monday, 19 July 2021                        11.0           372.75
#  Tuesday, 27 July 2021                       11.5           410.00
#
#                         Limuru Tea Co. Ltd Ord 20.00  Sasini Ltd Ord 1.00  \
# Date
#  Thursday, 13 May 2021                         340.0                18.80
#  Friday, 21 May 2021                           340.0                18.55
#  Tuesday, 25 May 2021                          340.0                18.40
#  Monday, 19 July 2021                          290.0                19.20
#  Tuesday, 27 July 2021                         280.0                19.95
#
#                         Williamson Tea Kenya Ltd Ord 5.00  \
# Date
# ...

# %%
df.set_index('Date',inplace=True)

# %%
df.head()
# Out:
#                         Eaagads Ltd Ord 1.25 AIMS  Kakuzi Ord.5.00  \
# Date
#  Thursday, 13 May 2021                       15.0           360.00
#  Friday, 21 May 2021                         15.0           360.00
#  Tuesday, 25 May 2021                        15.0           360.00
#  Monday, 19 July 2021                        11.0           372.75
#  Tuesday, 27 July 2021                       11.5           410.00
#
#                         Limuru Tea Co. Ltd Ord 20.00  Sasini Ltd Ord 1.00  \
# Date
#  Thursday, 13 May 2021                         340.0                18.80
#  Friday, 21 May 2021                           340.0                18.55
#  Tuesday, 25 May 2021                          340.0                18.40
#  Monday, 19 July 2021                          290.0                19.20
#  Tuesday, 27 July 2021                         280.0                19.95
#
#                         Williamson Tea Kenya Ltd Ord 5.00  \
# Date
# ...

# %%
df.shape
# Out:
# (107, 60)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 107 entries,  Thursday, 13 May 2021 to  Thursday, 13 January 2022
# Data columns (total 60 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   Eaagads Ltd Ord 1.25 AIMS                     107 non-null    float64
#  1   Kakuzi Ord.5.00                               107 non-null    float64
#  2   Limuru Tea Co. Ltd Ord 20.00                  107 non-null    float64
#  3   Sasini Ltd Ord 1.00                           107 non-null    float64
#  4   Williamson Tea Kenya Ltd Ord 5.00             107 non-null    float64
#  5   Car and General (K) Ltd Ord 5.00              107 non-null    float64
#  6   Absa Bank Kenya PLC                           107 non-null    float64
#  7   BK Group PLC                                  107 non-null    float64
#  8   Diamond Trust Bank Kenya Ltd Ord 4.00         107 non-null    float64
# ...

# %% [markdown]
# #### Data Cleaning
#
# __Kurwitu Venture Stock__

# %%
df.loc[:,'Kurwitu Ventures']
# Out:
# Date
#  Thursday, 13 May 2021         1,500.00
#  Friday, 21 May 2021           1,500.00
#  Tuesday, 25 May 2021          1,500.00
#  Monday, 19 July 2021          1,500.00
#  Tuesday, 27 July 2021         1,500.00
#                                  ...
#  Wednesday, 05 January 2022    1,500.00
#  Thursday, 06 January 2022     1,500.00
#  Friday, 07 January 2022       1,500.00
#  Tuesday, 11 January 2022      1,500.00
#  Thursday, 13 January 2022     1,500.00
# Name: Kurwitu Ventures, Length: 107, dtype: object

# %%
df['Kurwitu Ventures'] = df['Kurwitu Ventures'].str.replace(",","")
df['Kurwitu Ventures'].head()
# Out:
# Date
#  Thursday, 13 May 2021    1500.00
#  Friday, 21 May 2021      1500.00
#  Tuesday, 25 May 2021     1500.00
#  Monday, 19 July 2021     1500.00
#  Tuesday, 27 July 2021    1500.00
# Name: Kurwitu Ventures, dtype: object

# %%
df['Kurwitu Ventures'].apply(lambda x: x.split('.')[0])
# Out:
# Date
#  Thursday, 13 May 2021         1500
#  Friday, 21 May 2021           1500
#  Tuesday, 25 May 2021          1500
#  Monday, 19 July 2021          1500
#  Tuesday, 27 July 2021         1500
#                                ...
#  Wednesday, 05 January 2022    1500
#  Thursday, 06 January 2022     1500
#  Friday, 07 January 2022       1500
#  Tuesday, 11 January 2022      1500
#  Thursday, 13 January 2022     1500
# Name: Kurwitu Ventures, Length: 107, dtype: object

# %%
df['Kurwitu Ventures']
# Out:
# Date
#  Thursday, 13 May 2021         1500.00
#  Friday, 21 May 2021           1500.00
#  Tuesday, 25 May 2021          1500.00
#  Monday, 19 July 2021          1500.00
#  Tuesday, 27 July 2021         1500.00
#                                 ...
#  Wednesday, 05 January 2022    1500.00
#  Thursday, 06 January 2022     1500.00
#  Friday, 07 January 2022       1500.00
#  Tuesday, 11 January 2022      1500.00
#  Thursday, 13 January 2022     1500.00
# Name: Kurwitu Ventures, Length: 107, dtype: object

# %%
df['Kurwitu Ventures'] = df['Kurwitu Ventures'].apply(lambda x: x.split('.')[0])
df['Kurwitu Ventures'].head()
# Out:
# Date
#  Thursday, 13 May 2021    1500
#  Friday, 21 May 2021      1500
#  Tuesday, 25 May 2021     1500
#  Monday, 19 July 2021     1500
#  Tuesday, 27 July 2021    1500
# Name: Kurwitu Ventures, dtype: object

# %%
df['Kurwitu Ventures'].astype(np.float64)
# Out:
# Date
#  Thursday, 13 May 2021         1500.0
#  Friday, 21 May 2021           1500.0
#  Tuesday, 25 May 2021          1500.0
#  Monday, 19 July 2021          1500.0
#  Tuesday, 27 July 2021         1500.0
#                                 ...
#  Wednesday, 05 January 2022    1500.0
#  Thursday, 06 January 2022     1500.0
#  Friday, 07 January 2022       1500.0
#  Tuesday, 11 January 2022      1500.0
#  Thursday, 13 January 2022     1500.0
# Name: Kurwitu Ventures, Length: 107, dtype: float64

# %%
df['Kurwitu Ventures'] = df['Kurwitu Ventures'].astype(np.float64)
df['Kurwitu Ventures'].head()
# Out:
# Date
#  Thursday, 13 May 2021    1500.0
#  Friday, 21 May 2021      1500.0
#  Tuesday, 25 May 2021     1500.0
#  Monday, 19 July 2021     1500.0
#  Tuesday, 27 July 2021    1500.0
# Name: Kurwitu Ventures, dtype: float64

# %%
np.float64
# Out:
# numpy.float64

# %%
df.head()
# Out:
#                         Eaagads Ltd Ord 1.25 AIMS  Kakuzi Ord.5.00  \
# Date
#  Thursday, 13 May 2021                       15.0           360.00
#  Friday, 21 May 2021                         15.0           360.00
#  Tuesday, 25 May 2021                        15.0           360.00
#  Monday, 19 July 2021                        11.0           372.75
#  Tuesday, 27 July 2021                       11.5           410.00
#
#                         Limuru Tea Co. Ltd Ord 20.00  Sasini Ltd Ord 1.00  \
# Date
#  Thursday, 13 May 2021                         340.0                18.80
#  Friday, 21 May 2021                           340.0                18.55
#  Tuesday, 25 May 2021                          340.0                18.40
#  Monday, 19 July 2021                          290.0                19.20
#  Tuesday, 27 July 2021                         280.0                19.95
#
#                         Williamson Tea Kenya Ltd Ord 5.00  \
# Date
# ...

# %% [markdown]
# #### Arrange Data in Chronological Order
#
# The most recent date should be on lower index.
#
# We have to reverse the dataframe

# %%
df[::-1]
# Out:
#              EGAD    KUKZ   LIMT   SASN     WTK   CGEN   ABSA    BKG    DTK  \
# Date
# 2021-05-13  15.00  360.00  340.0  18.80  146.75  20.50   8.80  26.00  65.00
# 2021-05-21  15.00  360.00  340.0  18.55  145.00  22.00   9.10  26.00  63.75
# 2021-05-25  15.00  360.00  340.0  18.40  145.00  24.20   9.22  26.00  63.25
# 2021-07-19  11.00  372.75  290.0  19.20  152.25  31.00  10.00  28.00  69.00
# 2021-07-27  11.50  410.00  280.0  19.95  134.00  35.20   9.74  29.00  66.25
# ...           ...     ...    ...    ...     ...    ...    ...    ...    ...
# 2022-01-05  12.85  420.00  320.0  19.95  130.75  30.60  11.75  29.50  59.75
# 2022-01-06  13.80  420.00  320.0  20.25  130.75  33.70  11.80  29.30  60.00
# 2022-01-07  13.80  420.00  320.0  21.25  132.00  37.05  11.80  29.05  60.00
# 2022-01-11  13.80  385.00  320.0  20.55  134.75  44.75  11.90  30.75  59.50
# 2022-01-13  12.90  385.00  320.0  22.20  130.00  54.00  11.80  30.00  59.00
#
# ...

# %% [markdown]
# #### Convert From String to pandas datetime
#
# the pandas method `pd.to_datetime()`

# %% [markdown]
# #####  Date Formats Using datetime module
#
# [Format Codes](https://docs.python.org/3/library/datetime.html#strftime-and-strptime-behavior)

# %%
df.index
# Out:
# Index([' Thursday, 13 January 2022', ' Tuesday, 11 January 2022',
#        ' Friday, 07 January 2022', ' Thursday, 06 January 2022',
#        ' Wednesday, 05 January 2022', ' Tuesday, 04 January 2022',
#        ' Monday, 03 January 2022', ' Friday, 31 December 2021',
#        ' Thursday, 30 December 2021', ' Wednesday, 29 December 2021',
#        ...
#        ' Monday, 09 August 2021', ' Friday, 06 August 2021',
#        ' Thursday, 05 August 2021', ' Wednesday, 04 August 2021',
#        ' Tuesday, 03 August 2021', ' Tuesday, 27 July 2021',
#        ' Monday, 19 July 2021', ' Tuesday, 25 May 2021',
#        ' Friday, 21 May 2021', ' Thursday, 13 May 2021'],
#       dtype='object', name='Date', length=107)

# %%
df.index = df.index.str.lstrip()
df.index
# Out:
# Index(['Thursday, 13 January 2022', 'Tuesday, 11 January 2022',
#        'Friday, 07 January 2022', 'Thursday, 06 January 2022',
#        'Wednesday, 05 January 2022', 'Tuesday, 04 January 2022',
#        'Monday, 03 January 2022', 'Friday, 31 December 2021',
#        'Thursday, 30 December 2021', 'Wednesday, 29 December 2021',
#        ...
#        'Monday, 09 August 2021', 'Friday, 06 August 2021',
#        'Thursday, 05 August 2021', 'Wednesday, 04 August 2021',
#        'Tuesday, 03 August 2021', 'Tuesday, 27 July 2021',
#        'Monday, 19 July 2021', 'Tuesday, 25 May 2021', 'Friday, 21 May 2021',
#        'Thursday, 13 May 2021'],
#       dtype='object', name='Date', length=107)

# %%
pd.to_datetime(df.index,format='%A, %d %B %Y')
# Out:
# DatetimeIndex(['2022-01-13', '2022-01-11', '2022-01-07', '2022-01-06',
#                '2022-01-05', '2022-01-04', '2022-01-03', '2021-12-31',
#                '2021-12-30', '2021-12-29',
#                ...
#                '2021-08-09', '2021-08-06', '2021-08-05', '2021-08-04',
#                '2021-08-03', '2021-07-27', '2021-07-19', '2021-05-25',
#                '2021-05-21', '2021-05-13'],
#               dtype='datetime64[ns]', name='Date', length=107, freq=None)

# %%
df.index = pd.to_datetime(df.index,format='%A, %d %B %Y')
df.head()
# Out:
#              EGAD   KUKZ   LIMT   SASN     WTK   CGEN   ABSA    BKG    DTK  \
# Date
# 2022-01-13  12.90  385.0  320.0  22.20  130.00  54.00  11.80  30.00  59.00
# 2022-01-11  13.80  385.0  320.0  20.55  134.75  44.75  11.90  30.75  59.50
# 2022-01-07  13.80  420.0  320.0  21.25  132.00  37.05  11.80  29.05  60.00
# 2022-01-06  13.80  420.0  320.0  20.25  130.75  33.70  11.80  29.30  60.00
# 2022-01-05  12.85  420.0  320.0  19.95  130.75  30.60  11.75  29.50  59.75
#
#              EQTY  ...    BAT   CARB    EABL  EVRD  FTGH  ORCH   MSC   UNGA  \
# Date               ...
# 2022-01-13  49.55  ...  440.0  10.80  151.50  0.96  1.34  10.4  0.27  27.10
# 2022-01-11  52.00  ...  445.0  10.85  161.00  0.88  1.31  10.4  0.27  27.65
# 2022-01-07  53.00  ...  442.0  10.90  164.75  0.94  1.30  10.4  0.27  27.65
# 2022-01-06  53.00  ...  442.0  10.90  160.75  0.99  1.29  10.4  0.27  27.65
# 2022-01-05  53.00  ...  442.0  10.90  163.75  0.99  1.26  10.4  0.27  27.65
#
#              SCOM  FAHR
# ...

# %%
df.to_csv('clean_stock_data.csv')

# %% [markdown]
# ### Simple plot using `plot()`

# %% [markdown]
# #### Subsetting the DataFrame to only include dates after August 2021

# %%
df2 = df.loc['2021-08-03':]

# %% [markdown]
# ### Save DataFrame to file
#
# > `df.to_csv('file_name.csv', index=False)`

# %%
df.head()
# Out:
#              EGAD   KUKZ   LIMT   SASN     WTK   CGEN   ABSA    BKG    DTK  \
# Date
# 2022-01-13  12.90  385.0  320.0  22.20  130.00  54.00  11.80  30.00  59.00
# 2022-01-11  13.80  385.0  320.0  20.55  134.75  44.75  11.90  30.75  59.50
# 2022-01-07  13.80  420.0  320.0  21.25  132.00  37.05  11.80  29.05  60.00
# 2022-01-06  13.80  420.0  320.0  20.25  130.75  33.70  11.80  29.30  60.00
# 2022-01-05  12.85  420.0  320.0  19.95  130.75  30.60  11.75  29.50  59.75
#
#              EQTY  ...    BAT   CARB    EABL  EVRD  FTGH  ORCH   MSC   UNGA  \
# Date               ...
# 2022-01-13  49.55  ...  440.0  10.80  151.50  0.96  1.34  10.4  0.27  27.10
# 2022-01-11  52.00  ...  445.0  10.85  161.00  0.88  1.31  10.4  0.27  27.65
# 2022-01-07  53.00  ...  442.0  10.90  164.75  0.94  1.30  10.4  0.27  27.65
# 2022-01-06  53.00  ...  442.0  10.90  160.75  0.99  1.29  10.4  0.27  27.65
# 2022-01-05  53.00  ...  442.0  10.90  163.75  0.99  1.26  10.4  0.27  27.65
#
#              SCOM  FAHR
# ...

# %%
df.to_csv('cleaned_stock.csv')

# %% [markdown]
# ### Customizing Plots

# %% [markdown]
# #### Customize Size

# %% [markdown]
# #### Customize color

# %% [markdown]
# #### Multiple Line Plots

# %% [markdown]
# ### Change Ticker Names

# %%
tickers = ['EGAD','KUKZ','LIMT',
           'SASN','WTK', 'CGEN',
           'ABSA','BKG','DTK',
           'EQTY','HFCK','IMH', 
           'KCB','NBK', 'NCBA',
           'SBIC','SCBK','COOP',
           'XPRS','KQ','LKL',
           'NBV', 'NMG','SMER',
           'SCAN','SGL','TPSE',
           'UCHM','ARM','BAMB',
           'CRWN','CABL','PORT',
           'KEGN','KPLC','TOTL',
           'UMME','BRIT','CIC',
           'JUB','KNRE','LBTY', 
           'SLAM','CTUM','HAFR',
           'KURV','OCH','TCL',
           'NSE','BOC','BAT',
           'CARB','EABL','EVRD',
           'FTGH','ORCH', 'MSC',
           'UNGA','SCOM','FAHR']

tickers
# Out:
# ['EGAD',
#  'KUKZ',
#  'LIMT',
#  'SASN',
#  'WTK',
#  'CGEN',
#  'ABSA',
#  'BKG',
#  'DTK',
#  'EQTY',
#  'HFCK',
#  'IMH',
#  'KCB',
#  'NBK',
#  'NCBA',
#  'SBIC',
#  'SCBK',
#  'COOP',
#  'XPRS',
#  'KQ',
#  'LKL',
#  'NBV',
#  'NMG',
#  'SMER',
#  'SCAN',
#  'SGL',
#  'TPSE',
#  'UCHM',
#  'ARM',
#  'BAMB',
#  'CRWN',
#  'CABL',
#  'PORT',
#  'KEGN',
#  'KPLC',
#  'TOTL',
#  'UMME',
#  'BRIT',
#  'CIC',
#  'JUB',
#  'KNRE',
#  'LBTY',
#  'SLAM',
#  'CTUM',
#  'HAFR',
#  'KURV',
#  'OCH',
#  'TCL',
#  'NSE',
#  'BOC',
#  'BAT',
#  'CARB',
#  'EABL',
#  'EVRD',
#  'FTGH',
#  'ORCH',
#  'MSC',
#  'UNGA',
#  'SCOM',
#  'FAHR']

# %%
# update ticker names for df
df.columns = tickers

# %%
df.columns
# Out:
# Index(['EGAD', 'KUKZ', 'LIMT', 'SASN', 'WTK', 'CGEN', 'ABSA', 'BKG', 'DTK',
#        'EQTY', 'HFCK', 'IMH', 'KCB', 'NBK', 'NCBA', 'SBIC', 'SCBK', 'COOP',
#        'XPRS', 'KQ', 'LKL', 'NBV', 'NMG', 'SMER', 'SCAN', 'SGL', 'TPSE',
#        'UCHM', 'ARM', 'BAMB', 'CRWN', 'CABL', 'PORT', 'KEGN', 'KPLC', 'TOTL',
#        'UMME', 'BRIT', 'CIC', 'JUB', 'KNRE', 'LBTY', 'SLAM', 'CTUM', 'HAFR',
#        'KURV', 'OCH', 'TCL', 'NSE', 'BOC', 'BAT', 'CARB', 'EABL', 'EVRD',
#        'FTGH', 'ORCH', 'MSC', 'UNGA', 'SCOM', 'FAHR'],
#       dtype='object')

# %%
df['KURV']
# Out:
# Date
#  Thursday, 13 May 2021         1500.0
#  Friday, 21 May 2021           1500.0
#  Tuesday, 25 May 2021          1500.0
#  Monday, 19 July 2021          1500.0
#  Tuesday, 27 July 2021         1500.0
#                                 ...
#  Wednesday, 05 January 2022    1500.0
#  Thursday, 06 January 2022     1500.0
#  Friday, 07 January 2022       1500.0
#  Tuesday, 11 January 2022      1500.0
#  Thursday, 13 January 2022     1500.0
# Name: KURV, Length: 107, dtype: float64

# %%
df['NBK']
# Out:
# Date
#  Thursday, 13 May 2021         4.12
#  Friday, 21 May 2021           4.12
#  Tuesday, 25 May 2021          4.12
#  Monday, 19 July 2021          4.12
#  Tuesday, 27 July 2021         4.12
#                                ...
#  Wednesday, 05 January 2022    4.12
#  Thursday, 06 January 2022     4.12
#  Friday, 07 January 2022       4.12
#  Tuesday, 11 January 2022      4.12
#  Thursday, 13 January 2022     4.12
# Name: NBK, Length: 107, dtype: float64

# %%
df.drop('NBK',axis='columns')
# Out:
#                               EGAD    KUKZ   LIMT   SASN     WTK   CGEN  \
# Date
#  Thursday, 13 May 2021       15.00  360.00  340.0  18.80  146.75  20.50
#  Friday, 21 May 2021         15.00  360.00  340.0  18.55  145.00  22.00
#  Tuesday, 25 May 2021        15.00  360.00  340.0  18.40  145.00  24.20
#  Monday, 19 July 2021        11.00  372.75  290.0  19.20  152.25  31.00
#  Tuesday, 27 July 2021       11.50  410.00  280.0  19.95  134.00  35.20
# ...                            ...     ...    ...    ...     ...    ...
#  Wednesday, 05 January 2022  12.85  420.00  320.0  19.95  130.75  30.60
#  Thursday, 06 January 2022   13.80  420.00  320.0  20.25  130.75  33.70
#  Friday, 07 January 2022     13.80  420.00  320.0  21.25  132.00  37.05
#  Tuesday, 11 January 2022    13.80  385.00  320.0  20.55  134.75  44.75
#  Thursday, 13 January 2022   12.90  385.00  320.0  22.20  130.00  54.00
#
#                               ABSA    BKG    DTK   EQTY  ...     BAT   CARB  \
# ...

# %%
df = df[::-1].copy()
df.head()
# Out:
#                               EGAD   KUKZ   LIMT   SASN     WTK   CGEN   ABSA  \
# Date
#  Thursday, 13 January 2022   12.90  385.0  320.0  22.20  130.00  54.00  11.80
#  Tuesday, 11 January 2022    13.80  385.0  320.0  20.55  134.75  44.75  11.90
#  Friday, 07 January 2022     13.80  420.0  320.0  21.25  132.00  37.05  11.80
#  Thursday, 06 January 2022   13.80  420.0  320.0  20.25  130.75  33.70  11.80
#  Wednesday, 05 January 2022  12.85  420.0  320.0  19.95  130.75  30.60  11.75
#
#                                BKG    DTK   EQTY  ...    BAT   CARB    EABL  \
# Date                                              ...
#  Thursday, 13 January 2022   30.00  59.00  49.55  ...  440.0  10.80  151.50
#  Tuesday, 11 January 2022    30.75  59.50  52.00  ...  445.0  10.85  161.00
#  Friday, 07 January 2022     29.05  60.00  53.00  ...  442.0  10.90  164.75
#  Thursday, 06 January 2022   29.30  60.00  53.00  ...  442.0  10.90  160.75
# ...

# %%
df.tail()
# Out:
#                         EGAD    KUKZ   LIMT   SASN     WTK  CGEN   ABSA   BKG  \
# Date
#  Tuesday, 27 July 2021  11.5  410.00  280.0  19.95  134.00  35.2   9.74  29.0
#  Monday, 19 July 2021   11.0  372.75  290.0  19.20  152.25  31.0  10.00  28.0
#  Tuesday, 25 May 2021   15.0  360.00  340.0  18.40  145.00  24.2   9.22  26.0
#  Friday, 21 May 2021    15.0  360.00  340.0  18.55  145.00  22.0   9.10  26.0
#  Thursday, 13 May 2021  15.0  360.00  340.0  18.80  146.75  20.5   8.80  26.0
#
#                           DTK   EQTY  ...     BAT   CARB    EABL  EVRD  FTGH  \
# Date                                  ...
#  Tuesday, 27 July 2021  66.25  48.50  ...  469.50  12.05  184.00  1.01  1.33
#  Monday, 19 July 2021   69.00  48.55  ...  445.00  12.00  187.75  1.04  1.32
#  Tuesday, 25 May 2021   63.25  42.05  ...  464.75  10.15  181.00  0.99  1.40
#  Friday, 21 May 2021    63.75  41.50  ...  470.00  10.40  174.00  1.04  1.35
# ...

# %% [markdown]
# ### Subplots

# %% [markdown]
# #### One row two plots

# %% [markdown]
# #### Customize subplots

# %% [markdown]
# ## Compare banking sector stock prices on subplots

# %% [markdown]
# ##### The Repetitive way

# %% [markdown]
# #### Using a `for loop`

# %% [markdown]
# ## Challenges:
#
# Your challenge is to plot stock performance for the Insurance sector.
#
# `'BRIT':'SLAM'`

# %%
### Your Solution Here



##
